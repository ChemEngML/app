# %%
! pip install pycaret full --user

# %%
! streamlit run app_py.py
# Out:
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8520
#   Network URL: http://138.38.121.116:8520
#
#                     Description                 Value
# 0                    Session id                   123
# 1                        Target  Water Flux, Jw (LMH)
# 2                   Target type            Regression
# 3           Original data shape             (234, 15)
# 4        Transformed data shape             (234, 27)
# 5   Transformed train set shape             (163, 27)
# 6    Transformed test set shape              (71, 27)
# 7              Numeric features                    11
# 8          Categorical features                     3
# 9      Rows with missing values                 12.4%
# 10                   Preprocess                  True
# 11              Imputation type                simple
# 12           Numeric imputation                  mean
# 13       Categorical imputation                  mode
# ...
